# %%
# importação de bibliotecas
import sys
import os
import plotly.express as px
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import pandas as pd

# %%
# Adiciona o diretório pai ao PYTHONPATH
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
from src.data_ingestion.reading_data import load_csv

# %%
# Carrega o DataFrame
# Código necessário para acessar a raiz do projeto
root = os.path.abspath(os.path.join(os.getcwd(), '..'))
df = load_csv('onlinefoods.csv', folder=os.path.join(root, 'data'))
# Out:
# Arquivo 'onlinefoods.csv' carregado com sucesso.

# %%
# Visualização inicial do dataframe
df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
# Configurações de visualização
sns.set_theme()  # isso configura automaticamente o estilo do matplotlib
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1. Análise do Perfil Demográfico

# %% [markdown]
# ## 1.1 Distribuição de idade

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='Age', bins=30)
plt.title('Distribuição de Idade dos Clientes')
plt.xlabel('Idade')
plt.ylabel('Contagem')
plt.show()

# %% [markdown]
# # 1.2 Análise por gênero e estado civil

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Gender', hue='Marital Status')
plt.title('Distribuição de Gênero por Estado Civil')
plt.show()

# %% [markdown]
# # 1.3 Análise de renda mensal

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, y='Monthly Income', order=df['Monthly Income'].value_counts().index)
plt.title('Distribuição de Renda Mensal')
plt.show()
